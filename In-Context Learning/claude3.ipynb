# %% [markdown]
# This notebook was run in Google Colab. To run every cell you need to upload the data set and prompts into the same folder. The code for evaluation was partially taken from others papers and merged together. Boilerplate code was typically generated using Claude 3 Opus and GPT-4 and then adjusted for our specific use case.

# %%
# !pip install anthropic
# !pip install sacrebleu
# !pip install rouge_score
# Out:
# Collecting anthropic
#   Downloading anthropic-0.21.3-py3-none-any.whl (851 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 851.6/851.6 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from anthropic) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from anthropic) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from anthropic)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from anthropic) (2.6.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: tokenizers>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from anthropic) (0.15.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from anthropic) (4.10.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->anthropic) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->anthropic) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->anthropic)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.1 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->anthropic)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.16.3)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.0->anthropic) (0.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (3.13.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (4.66.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (6.0.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (24.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic) (2.0.7)
# Installing collected packages: h11, httpcore, httpx, anthropic
# Successfully installed anthropic-0.21.3 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0
# Collecting sacrebleu
#   Downloading sacrebleu-2.4.1-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 1.8 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (1.25.2)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (4.9.4)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-2.8.2 sacrebleu-2.4.1
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.25.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.2)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=671501b248b47126a5576b17cccb8b09a85d68702c878a2cabbba82cc4ba0b86
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %% [markdown]
# # Import libraries

# %%
import anthropic
import pathlib
import textwrap
import json
import time
import pickle
import sacrebleu
import numpy as np
from IPython.display import display
from IPython.display import Markdown
import nltk
from nltk.translate import meteor
from nltk.tokenize import word_tokenize
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu
from nltk.translate.bleu_score import SmoothingFunction
nltk.download("wordnet")
nltk.download("punkt")
from rouge_score import rouge_scorer
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# # Claude API key

# %%
client = anthropic.Anthropic(
    api_key="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",
)

# %% [markdown]
# # Functions

# %%
# Function that retrieves the whole dialog chat from a single conversation
def sort_and_track_dialog(dialog):
    seeker_list = []
    supporter_list = []
    first_speaker = None  # Track who starts the conversation

    current_speaker = None
    current_content = ""

    for i, entry in enumerate(dialog):
        speaker = entry['speaker']
        content = entry['content']

        # Determine the first speaker
        if i == 0:
            first_speaker = speaker

        if speaker == current_speaker:
            # Concatenate content if the same speaker continues
            current_content += " " + content
        else:
            # Save the previous speaker's content if any
            if current_content:
                if current_speaker == 'seeker':
                    seeker_list.append(current_content)
                elif current_speaker == 'supporter':
                    supporter_list.append(current_content)

            # Update the current speaker and content with the new entry
            current_speaker = speaker
            current_content = content

    # Add the last speaker's content to the respective list
    if current_content:
        if current_speaker == 'seeker':
            seeker_list.append(current_content)
        elif current_speaker == 'supporter':
            supporter_list.append(current_content)

    return seeker_list, supporter_list, first_speaker

# %%
def create_chat_history_claude(prompt, model_start, seeker_list, supporter_list, first_speaker):
    # Initialize chat_history with the prompt and initial model message
    chat_history = [
        {"role": "user", "content": prompt},
        {"role": "assistant", "content": model_start}
    ]

    # Adjust initial model message if the first speaker is 'supporter'
    supporter_start_idx = 0
    if first_speaker == "supporter" and supporter_list:
        # Add the first message of the supporter_list to the model_start content
        chat_history[1]["content"] += "\n" + supporter_list[0]
        supporter_start_idx = 1  # Start from the second message for supporter

    # Determine the starting point for seeker messages
    seeker_start_idx = 0

    # Calculate the total iterations needed
    max_iterations = max(len(seeker_list) - seeker_start_idx, len(supporter_list) - supporter_start_idx)

    # Alternating between seeker and supporter messages
    for i in range(max_iterations):
        if i + seeker_start_idx < len(seeker_list):
            chat_history.append({
                "role": "user",
                "content": seeker_list[i + seeker_start_idx]
            })
        if i + supporter_start_idx < len(supporter_list):
            chat_history.append({
                "role": "assistant",
                "content": supporter_list[i + supporter_start_idx]
            })

    return chat_history

# %%
def generate_model_responses_claude(dialog, prompt, model_start):
    # Get seeker_list, supporter_list, and who starts the conversation
    seeker_list, supporter_list, first_speaker = sort_and_track_dialog(dialog)

    # Create chat history for Claude3
    chat_history = create_chat_history_claude(prompt, model_start, seeker_list, supporter_list, first_speaker)

    # Initialise model responses and golden responses
    model_responses = []
    golden_responses = []

    # Determine max index for generating responses
    max_index = len(chat_history) - 4

    for i in range(0, max_index, 2):
        try:
            # Current history
            current_history = chat_history[:i+3]  # Include the next user message for context

            # Send message to Claude3 and get model response
            message = client.messages.create(
                model="claude-3-haiku-20240307",
                max_tokens=1024,
                messages=current_history
            )
            print('Sleeping after calling API')
            time.sleep(2)

            # Extract model response
            model_response = message.content[0].text
            model_responses.append(model_response)

            #print(current_history)
            #print(model_response)

            # Save golden responses
            golden_response = chat_history[i+3]["content"]
            golden_responses.append(golden_response)

        except Exception as e:
            print(f"An error occurred: {e}")
            break  # or use `continue` depending on the desired behavior

    return model_responses, golden_responses

# %% [markdown]
# # Hyperparameters

# %%
# File path
file_path = 'ESConv.json'

# Load the JSON data
with open(file_path, 'r') as file:
    data = json.load(file)

# Get prompt
file_name = '40_example_conversations_prompt'
file_path = f'{file_name}.txt'
with open(file_path, 'r') as file:
    prompt = file.read()

# First model response for chat history
model_start = "I understand that I should provide psychological help and that the previous message provides a suitable guideline. In the following conversation, I will only reply in 1-2 sentences:"

# Save path for model and golden responses
save_golden_responses = f'{file_name}_all_golden_responses.pkl'
save_model_responses = f'{file_name}_all_model_responses.pkl'

# %% [markdown]
# # Load test data

# %%
# Replace 'file_path' with the path to your text file
file_path = 'testdata.txt'

# Initialize a list to store the JSON objects
testdata = []

# Open the file and read line by line
with open(file_path, 'r') as file:
    for line in file:
        # Parse each line as a JSON object and append to the list
        json_line = json.loads(line.strip())
        testdata.append(json_line)

# Renaming the keys as per the requirements
for conversation in testdata:
    for message in conversation['dialog']:
        # Renaming 'text' to 'content'
        message['content'] = message.pop('text')
        # Renaming 'speaker' values
        if message['speaker'] == 'sys':
            message['speaker'] = 'supporter'
        elif message['speaker'] == 'usr':
            message['speaker'] = 'seeker'

# %%
len(testdata)
# Out:
# 195

# %% [markdown]
# # Generate model responses and golden responses for all

# %%
# Initialise list of lists for model responses and golden responses
all_model_responses = []
all_golden_responses = []

# Iterate over all test conversations
for i in range(0, len(testdata)):

  # Print statement
  print(f'Starting to generate model responses for test conversation {i} of {len(testdata)}')

  # Get dialog data
  dialog = testdata[i]['dialog']

  # Get seeker_list, supporter_list and who starts the conversation
  seeker_list, supporter_list, first_speaker = sort_and_track_dialog(dialog)

  # Create chat history
  chat_history = create_chat_history_claude(prompt, model_start, seeker_list, supporter_list, first_speaker)

  # Generate model responses
  model_responses, golden_responses = generate_model_responses_claude(dialog, prompt, model_start)

  # Add model and golden responses to list of lists
  all_model_responses.append(model_responses)
  all_golden_responses.append(golden_responses)
# Out:
# Starting to generate model responses for test conversation 0 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 1 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 2 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 3 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 4 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 5 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 6 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 7 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 8 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 9 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 10 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 11 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 12 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 13 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 14 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 15 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 16 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 17 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 18 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 19 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 20 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 21 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 22 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# Starting to generate model responses for test conversation 23 of 195
# Sleeping after calling API
# Sleeping after calling API
# Sleeping after calling API
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 24 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 25 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 26 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 27 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 28 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 29 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 30 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 31 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 32 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 33 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 34 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 35 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 36 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 37 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 38 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 39 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 40 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 41 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 42 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 43 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 44 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 45 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 46 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 47 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 48 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 49 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 50 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 51 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 52 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 53 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 54 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 55 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 56 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 57 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 58 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 59 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 60 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 61 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 62 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 63 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 64 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 65 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 66 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 67 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 68 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 69 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 70 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 71 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 72 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 73 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 74 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 75 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 76 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 77 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 78 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 79 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 80 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 81 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 82 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 83 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 84 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 85 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 86 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 87 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 88 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 89 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 90 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 91 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 92 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 93 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 94 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 95 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 96 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 97 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 98 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 99 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 100 of 195
# ...
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 164 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 165 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 166 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 167 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 168 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 169 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 170 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 171 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 172 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 173 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 174 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 175 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 176 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 177 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 178 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 179 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 180 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 181 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 182 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 183 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 184 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 185 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 186 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 187 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 188 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 189 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 190 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 191 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 192 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 193 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}
# Starting to generate model responses for test conversation 194 of 195
# An error occurred: Error code: 429 - {'type': 'error', 'error': {'type': 'rate_limit_error', 'message': 'Number of request tokens has exceeded your rate limit (https://docs.anthropic.com/claude/reference/rate-limits). Please reduce the the prompt length or the maximum tokens requested, or try again later. You may also contact sales at https://www.anthropic.com/contact-sales to discuss your options for a rate limit increase.'}}

# %% [markdown]
# # Save model

# %%
# Save all_model_responses and all_golden_responses to disk
with open(save_model_responses, 'wb') as f:
    pickle.dump(all_model_responses, f)

with open(save_golden_responses, 'wb') as f:
    pickle.dump(all_golden_responses, f)

print('All model and golden responses were saved.')
# Out:
# All model and golden responses were saved.

# %% [markdown]
# # Load model responses

# %%
# Load all_model_responses from disk
with open(save_model_responses, 'rb') as f:
    all_model_responses = pickle.load(f)

# Load all_golden_responses from disk
with open(save_golden_responses, 'rb') as f:
    all_golden_responses = pickle.load(f)

print('All model and golden responses were loaded.')
# Out:
# All model and golden responses were loaded.

# %%
all_golden_responses = all_golden_responses[:23]
all_model_responses = all_model_responses[:23]

# %%
all_model_responses
# Out:
# [["I'm sorry to hear you're feeling sad. Can you tell me more about what's causing those feelings? I'm here to listen without judgment and provide the support you need.",
#   'The holidays can be a difficult time for many people. What is causing you the most stress and nervousness regarding the holidays?',
#   "I'm so sorry to hear about the tension with your dad. That must be incredibly difficult, especially with having to go home for the holidays. Your feelings are valid. Have you considered reaching out to your school's counseling services for support during this time?",
#   "That sounds like an incredibly difficult situation. Being stuck in close quarters with someone you're not speaking to must feel very stressful and anxiety-provoking. I can understand why you're feeling so nervous about going home for the holidays. Have you considered reaching out to any campus resources or counselors to see if they can provide support or guidance during this time? You deserve to feel safe and comfortable, especially in your own home.",
#   "I see, that's so stressful with the uncertainty around COVID and having to potentially return home full-time. Not having a support system at home must make it feel even more isolating. The hamster at school is a plus, at least you have that companionship there. I really hope you're able to get through the break with minimal conflict, and that the situation improves soon. Please don't hesitate to reach out if you need someone to talk to.",
#   "I understand, it's not selfish at all to be worried about your own situation, especially during the holidays when family dynamics can be so complex. I'm really glad you're able to bring your hamster home - that will definitely provide some comfort and familiarity. Focus on the little joys, like bonding with your pet. And remember, this situation is temporary. You've got this, and you're not alone.",
#   "That's such a wonderful idea! Introducing your hamster to your niece will provide you both with some much needed joy and distraction during this stressful time. Having that special connection, even if just for a little while, can make all the difference. I'm glad you have that to look forward to. Don't hesitate to reach out if you need any other support navigating this challenging situation. You've got this!",
#   "I understand not having transportation adds an extra challenge. But the fact that you're determined to make it work, even in small ways like trying to have your niece over, shows great resilience. Not having the freedom of your own car is tough, but you're taking it one step at a time. That's incredibly admirable. I hope you're able to find ways, even if they're limited, to find joy and comfort during this difficult time.",
#   "I'm so glad I could provide that suggestion! Feel free to reach out if you ever need any other ideas or just someone to talk to during this challenging time. Wishing you all the best with navigating the holidays."],
#  ["Hi Tom, I'm here to listen and provide the best support I can. What's going on that has you seeking help?",
#   "I'm sorry to hear you're feeling so stressed and worried about the possibility of losing your job. Not knowing the future can be very unsettling, but try not to catastrophize. Focus on what you can control, like updating your resume and networking, rather than ruminating on the worst-case scenario. Your family needs you to stay strong and resilient during this challenging time.",
#   'I understand this is a very stressful situation. Your best approach would be to have an open and honest discussion with your boss about your concerns. Focus on suggesting creative solutions that could allow you to retain your job during this difficult time.',
#   'I understand this is a very stressful situation, but try to stay positive. Focus on exploring new job opportunities and seek support from your family and community during this time. Remember, this is temporary and you have the strength to get through this.',
#   "I understand your concerns. During these difficult times, it's important to take care of your mental health. Consider speaking to a financial advisor to explore options for managing your expenses if you do lose your job. Also, look into government assistance programs that may be available to support you and your family. Remain hopeful - with your skills and determination, you can get through this challenge.",
#   "I understand this is a very stressful situation. However, there are some things you can focus on to help manage the anxiety and uncertainty. First, I would suggest speaking openly with your boss about your concerns and see if there are any temporary or alternative arrangements that could be made to keep you employed. Secondly, start exploring other job options and networking, even if it feels daunting. Having a plan B can help provide a sense of control. Finally, be sure to take time for self-care - exercise, connect with loved ones, and practice relaxation techniques. This will help you cope better mentally and emotionally during this challenging time. I'm here to support you through this.",
#   "Okay, I understand your concern about losing your job as an architect during this challenging time. Here are a couple suggestions that may help:\n\n1. Reach out to your professional network and let them know you are looking. They may be able to connect you with potential opportunities.\n\n2. Consider expanding your skills or services you offer as an architect. This could make you more competitive in the job market.\n\nThe most important thing is to stay positive and proactive. I know it's stressful, but try not to lose hope. With some resourcefulness, I believe you can get through this difficult period. Please let me know if you need any other suggestions.",
#   "I understand this is a very stressful time for you, but I want to reassure you that there are ways to cope and get through this. The most important thing is to not lose hope. I know it's not easy, but try to stay positive and focus on the things you can control. Have you considered reaching out to your network of colleagues or professional associations to see if there are any job opportunities or support available? It's also crucial to take care of your mental health during this time - make sure to prioritize self-care activities like exercise, meditation, or speaking with a therapist. Remember, this situation is temporary, and with the right mindset and support, you can get through this. I'm here if you ever need someone to talk to.",
#   "I'm so sorry to hear you're going through this difficult time. Losing a job can be incredibly stressful, especially with a family to support. While the situation may seem bleak, try not to lose hope. There may be ways to convince your boss to keep you on, even if it's reduced hours or temporary. If that's not possible, focus on taking care of yourself mentally and emotionally. Seek support from loved ones, practice self-care, and remember that this too shall pass. You're a talented architect, and I have faith you'll find another opportunity, even if it takes time. Wishing you all the best."],
#  ["I'm sorry to hear you're struggling with a lack of friends. That can be a very difficult and isolating experience. Have you considered reaching out to join any local groups or activities that interest you? Sometimes putting yourself out there, even when it's hard, can help build new connections.",
#   "That must be really difficult to feel so alone without having close friends to connect with. Building meaningful friendships can take time and effort, but it's so worth it for our overall wellbeing. Have you considered joining any local clubs or groups to meet new people who share your interests? Even small steps can make a big difference.",
#   'I understand that feeling. It can be difficult to open up to family sometimes. Have you considered reaching out to a counselor or therapist? They can provide a safe, judgment-free space to work through these feelings of loneliness.',
#   "Ah I understand. Well, those can be a great option to explore when you're looking to make new friends. The process can feel a bit awkward at first, but many people have found success connecting with like-minded individuals that way. I'd be happy to provide some recommendations on reputable friendship apps if you're interested in giving that a try. The most important thing is not to lose hope - making meaningful connections is possible, it just may take some time and effort. How does that sound to you?",
#   "I understand, having an in-person local friend is ideal. Since the friend apps may not be the full solution, have you considered joining any local clubs, groups or activities in your community? Things like book clubs, hobby groups, sports leagues etc. can be a great way to meet people with shared interests that live nearby. That could be a good starting point to build those face-to-face connections you're looking for. What do you think - is that something you'd be open to trying?",
#   "I understand, that lack of courage can be really tough. Making new friends as an adult can feel really intimidating. Have you thought about starting small, maybe by trying to strike up a conversation with a neighbor or coworker? Just a friendly chat to get used to being more social. Building up that courage one small step at a time could really help you feel more comfortable putting yourself out there to meet potential new friends in your local area. I know it's not easy, but I believe in you - you've got this!",
#   "Exactly! The friendship apps allow you to connect with people in your local area first, chat with them, and get to know them a bit before taking that next step to actually meet in person. That can make it much less daunting, especially if you're feeling a bit nervous about putting yourself out there. The online connection first can really help build that confidence to then meet up face-to-face. Does that make sense? I really think trying an app like that could be a great first step for you."],
#  ['Hello, how can I assist you today?',
#   "I understand this is a difficult and sensitive situation. Avoiding confrontation may seem easier, but addressing your concerns openly and compassionately with your partner is often the best path forward, even though it may be challenging. I'm happy to discuss strategies that could help you navigate this in a healthy manner.",
#   'I would caution against ignoring suspicions of infidelity. While the fear of losing a relationship is understandable, addressing the issue directly, even if difficult, may be the healthiest path forward.',
#   "I know it's an incredibly difficult situation, but continuing to ignore the issue is unlikely to resolve it in a healthy way. Have you considered speaking openly with your girlfriend about your concerns? Addressing it directly, even if it's scary, may be the best path forward, whether that means working to rebuild trust or realizing you need to move on. I'm happy to discuss strategies for having that tough conversation in a constructive manner, if you'd find that helpful.",
#   "I understand the desire to hold onto something that makes you feel good, even if deep down you know it's not right. However, staying in a relationship built on insecurity and a lack of trust will only lead to more pain in the long run. Your self-worth is not defined by who you are with - you have inherent value regardless of your partner's attractiveness. I encourage you to have an honest conversation with your girlfriend, and be open to the possibility that walking away may be the healthiest choice, even if it's difficult in the moment.",
#   "I understand this is a very difficult and stressful situation. However, making assumptions or ignoring the issue will only lead to more pain down the line. The healthiest approach is to have an open and honest discussion with her about your concerns. This may be challenging, but it's the only way to address the trust issues and determine the best path forward, whether that's rebuilding the relationship or moving on. I know it's scary, but being vulnerable and communicating your feelings is the brave thing to do. You deserve a partner who values you and is faithful. I'm happy to discuss strategies for having this conversation if that would be helpful.",
#   "I understand your hesitation to confront her directly, as that can feel incredibly vulnerable. However, avoiding the issue will only prolong the pain and uncertainty. The healthiest approach is to have an open and honest conversation with her. Approach it from a place of concern, not accusation. Let her know you've noticed some changes in her behavior that are concerning you, and ask if there's anything going on you should know about. Be prepared to listen without judgment, and focus on rebuilding trust, not placing blame. It won't be easy, but addressing it head-on is the only way to move forward, whether that's resolving the issues or respectfully parting ways. You deserve to be in a relationship built on mutual trust and respect.",
#   "I know this is a very difficult and sensitive situation, but my advice would be to have an open and honest conversation with her about your concerns. Avoiding the issue or making assumptions will only lead to more anxiety and hurt down the line. Even though it's scary, addressing it directly, in a caring way, is the best path forward - whether that means resolving the misunderstanding or deciding to part ways. You deserve to be in a relationship built on mutual trust and respect. I'm happy to provide more support as you navigate this.",
#   "I think the healthiest thing is to have an open and honest conversation with your girlfriend. Even if the truth is difficult, it's better to address the situation directly rather than letting the fear and uncertainty fester. Approach it from a place of care and vulnerability, not accusation. If she is indeed unfaithful, then it may be time to re-evaluate the relationship. But avoiding the issue will only prolong the pain. You deserve clarity and peace of mind, one way or the other. I know it's scary, but you have to put your wellbeing first.",
#   "I understand that this is a very difficult and vulnerable position to be in. Your feelings of low self-esteem are valid, and it's understandable that having a partner perceived as a '9' could provide a boost. However, true fulfillment and self-worth needs to come from within, not from external validation. I would gently encourage you to have an open and honest conversation with your girlfriend. Her reaction, whether positive or negative, will provide valuable insight. Most importantly, remember that your value is not determined by your appearance or your partner's - you deserve respect, loyalty and love, regardless. Taking care of your mental health should be the priority here. I'm happy to continue discussing strategies to boost your self-confidence in a healthy way."],
#  ["I'm sorry to hear you're feeling anxious and stressed with your upcoming deadlines. It's understandable to feel that way when academic pressure is high. Have you tried incorporating relaxation techniques, like deep breathing or meditation, into your routine to help manage the stress?",
#   'I understand the stress of impending academic deadlines can be overwhelming. However, try to focus on tackling one task at a time to avoid feeling anxious. Prioritize your time and create a study plan to help you stay on track. Remember to also take breaks to recharge and take care of your well-being.',
#   "I understand the temptation to procrastinate with online classes, but it's important to stay on top of your work to avoid added stress later. Have you considered breaking down your assignments into smaller, more manageable tasks?",
#   'I understand, heavy course loads can feel overwhelming, especially with online learning. Have you considered breaking tasks into smaller, more manageable steps? That can help reduce anxiety and boost productivity.',
#   "I understand the stress of looming deadlines, especially when studying online. Have you considered breaking down the assignments and exams into smaller, more manageable tasks? Taking regular breaks and practicing self-care can also help you stay focused and motivated. Remember, you've got this - take it one step at a time, and don't hesitate to reach out for support if you need it.",
#   'I see, the in-person environment can be really helpful for focus and motivation. With the upcoming deadlines, what are some strategies you can use to manage your time and stress effectively?',
#   "I understand, the pandemic has made it much more challenging to stay motivated and on track with studies. But you recognize you've been procrastinating, which is the first step to getting back on top of things. I encourage you to make a detailed study plan to help you meet those deadlines successfully. You've done online learning before, so you can absolutely do this. One step at a time, and don't be too hard on yourself - these are unprecedented times.",
#   "That's good to hear you're taking breaks. It's important to balance your workload and give yourself time to recharge. Staying focused can be challenging, but managing your time and energy wisely will help you succeed. Remember to be patient with yourself - you've got this!",
#   'I understand, the lack of routine and change of pace can really take a toll. Maybe try scheduling in some small activities or outings, even just a walk around the block, to break up the monotony. Small steps like that can help regain a sense of structure and refresh the mind.',
#   "I understand that it can be really difficult to stay motivated and on top of things during these unusual times. The disruption to our normal routines and lack of external stimulation can make it hard to find that same sense of urgency and discipline we're used to. But try not to be too hard on yourself - this is a challenging situation for everyone. You're still doing the work and pushing through, and that's what matters most. Maybe try setting some small, achievable goals for yourself each day or week, and celebrate those little wins. And be sure to build in some enjoyable breaks, whether that's listening to music, getting some exercise, or just taking time to yourself. Small steps can really add up. You've got this!",
#   "Absolutely, having a consistent routine at home can really help provide structure during these uncertain times. Even something as simple as a daily walk or 20 minutes of yoga can make a big difference in boosting your mood and productivity. The key is finding an activity you enjoy so it doesn't feel like a chore. Maybe experiment with different workouts until you find what works best for you.",
#   "I'm glad to hear that our conversation has helped provide some optimism. It's great that you recognize working out helps you focus - trying to incorporate that back into your routine, even just a little at a time, could really make a difference. Be patient with yourself, these are challenging times, but your motivation and drive will come back. I'm confident you've got this!",
#   "Yes, I'm glad our conversation has helped you feel more optimistic. Remember to be kind to yourself - this pandemic has been hard on everyone. Establishing a regular workout routine can definitely help provide structure and boost productivity. Why don't you try scheduling a daily 30-minute workout during one of your study breaks? That could help re-energize you. And don't be too hard on yourself about the procrastination - just focus on taking it one step at a time. You've got this!",
#   "I'm so glad I could provide some helpful perspective! Setting daily goals and creating a schedule can make a big difference when feeling overwhelmed. Remember to also be kind to yourself - these are challenging times and you're doing the best you can. Wishing you all the best with your studies and taking care of your mental health. Don't hesitate to reach out if you need more support."],
#  ['Your friends should not shame you. Their behavior is unacceptable. You deserve to be treated with respect.',
#   'Your friends should not shame you for your personal decisions about charitable giving. Charitable contributions are a personal choice, and you should not feel guilty for deciding how to allocate your resources.',
#   "I understand that times are tough financially, and you should not feel obligated to donate more than what you can reasonably afford. Your friends' judgment is unfair - focus on your own wellbeing during this difficult period.",
#   'Your friends should be understanding of your financial situation during these difficult times. Shaming you is not the appropriate way to encourage charitable giving.',
#   'I understand this is a very difficult situation. My advice would be to have an open and honest conversation with them about how their actions are making you feel. Set clear boundaries about what is and is not acceptable. If they continue to shame and guilt you, you may need to reconsider those friendships. Your wellbeing should be the priority here.',
#   'I see. In that case, I would suggest having an honest and open conversation with them. Explain your current financial situation and how the pandemic has impacted you. Emphasize that while you care about the cause, you are not in a position to donate as much right now. Hopefully, they will understand and be more compassionate. If they continue to shame you, you may need to reconsider the friendship.',
#   "that sounds like a great compromise. Focus on what you can reasonably contribute, whether it's time or money, and don't let your friends shame you. Their behavior is unfair, especially given the challenging circumstances you're facing. I'd suggest having an open, honest conversation with them about your situation if you feel comfortable doing so. They may be more understanding than you expect.",
#   "That's great you were able to contribute more in the past. Right now, focus on taking care of yourself first. Offering your time may be a good alternative if you are able. Ultimately, your friends should be understanding of your current situation rather than shaming you.",
#   "I'm really sorry you are going through this difficult situation with your friends. It's understandable to feel hurt and frustrated when people don't understand your circumstances. I would suggest trying to have an open and honest conversation with them, if possible. Explain that while you value their work, your own financial situation has changed due to COVID-19 and you're doing the best you can. Suggest volunteering your time instead, if that's an option. Ultimately, true friends should be understanding and supportive, not guilt-tripping you. Remember to focus on taking care of yourself during this challenging time.",
#   "that's a great idea! explain to them that your situation has changed but you are finding other ways to contribute that work for you right now. true friends will understand.",
#   "that's a great idea to offer your time instead, your friends should be understanding of your current financial situation. Focusing on what you can contribute, whether that's time or money, is much more valuable than guilt-tripping.",
#   "You're absolutely right. Your friends should not be shaming you without understanding your full circumstances. Donating time can be just as valuable, if not more so, than monetary donations. I would suggest having an open and honest conversation with them, explaining your current financial situation and the ways you are still trying to contribute. True friends should be understanding and supportive, not judgmental. If they cannot be, then you may need to reconsider these relationships.",
#   "That's a very mature approach. Focusing on ways you can contribute that align with your current circumstances, while maintaining your self-respect, is the healthiest way forward. Your friends may not understand, but that's on them, not you. Stay true to yourself.",
#   "I understand this is a difficult situation. The most important thing is to take care of yourself first. Your friends should not be shaming you - that is unfair and unkind. Consider focusing your energy on finding ways to contribute that feel meaningful to you, whether that's volunteering time or something else. Their opinions do not define your worth. Stay strong and remember to be compassionate with yourself.",
#   'I understand your hesitation in sharing your current financial struggles with them. However, being honest and upfront, even if they may not initially believe you, is often the best policy. Explain your situation calmly and focus on how you can contribute in other meaningful ways, like volunteering. If they remain unsupportive, consider whether these are truly friends worth keeping. The most important thing is taking care of yourself during this challenging time.',
#   'I understand that can be difficult, but your health and well-being need to be the priority. If these friends are not understanding of your current situation, you may need to distance yourself from them for now. Focus on self-care and surround yourself with people who truly support you, even if that means fewer social engagements for the time being. Your true friends will understand and be there for you.',
#   "You're welcome. I hope you're able to have an open and honest conversation with your friends about your current situation. Their judgment is unfair, and focusing on what you can contribute, whether time or money, is what matters most. Wishing you all the best in navigating this. Take care."],
#  ["Hello. I'm doing well, thank you for asking. How can I assist you today?",
#   "I'm sorry to hear you've been feeling this way. Being passed over at work can be very discouraging. Have you considered speaking with your manager to understand why this is happening and what you can do to improve the situation?",
#   'Have you spoken to your manager about your concerns? They may be able to provide constructive feedback to help you improve.',
#   'I would suggest speaking candidly with your manager about your concerns, and also considering whether this job is the right fit for your needs.',
#   'I understand the frustration of not being able to communicate directly with your supervisor. Perhaps you could request a meeting to discuss your concerns?',
#   'I understand the depression is tough to manage. Have you considered speaking to a counselor or therapist? They could provide personalized strategies to help lift your mood.',
#   "I'm sorry to hear that depression has been an ongoing issue for you. In a case like this, I would suggest speaking to a mental health professional who can provide personalized guidance. They can help you develop coping strategies and address the root causes. Taking that first step can make a big difference.",
#   "I understand the struggle of trying to reach your boss during this time. Perhaps start by documenting your concerns and then request a meeting, even if it has to be virtual, to discuss what's happening and how you can get back on track. Taking that first step can help ease the anxiety.",
#   "Yes, that's a great approach. Keep focusing on doing your best work, and try not to take the benching personally. Reaching out to your boss, even if they are hard to get ahold of, shows initiative and care about your role. Keep advocating for yourself, but also practice self-compassion during this challenging time.",
#   "You're welcome. I know it's not easy, but keeping focus on doing good work and being patient with your manager's availability is a good approach. Wishing you the best in getting the clarity you need.",
#   "I'm glad I could offer a different perspective that seems helpful. Wishing you the very best in resolving this difficult situation at work.",
#   "I'm so glad I could provide some helpful perspective. Trying yoga sounds like an excellent idea to manage the anxiety in the meantime. Wishing you the very best in speaking with your manager and finding a resolution. Have a wonderful evening!",
#   "I'm glad I could provide some reassuring perspectives on your situation. Wishing you all the best in getting the clarity you need from your manager. Have a wonderful evening!",
#   "Absolutely, try to stay positive and focus on what you can control. Wishing you the very best in getting to the bottom of this and finding a resolution. Don't hesitate to reach out if you need any other suggestions."],
#  ["That's great to hear. It's important to take care of your mental and physical well-being, especially during challenging times.",
#   "I see. It can be challenging when a friend has a hard time adjusting to the changes in your life as you've grown up. Have you tried having an open and honest conversation with her about how her actions make you feel?",
#   "I'm sorry to hear that your friend is having trouble seeing you as the capable adult you've become. It can be really frustrating when someone doesn't recognize the growth and maturity we've achieved. Have you considered having an open and honest conversation with her about how her behavior makes you feel?",
#   'I would suggest having an open and honest conversation with her first. Explain how her treatment of you makes you feel, and see if she is willing to adjust her behavior. If not, you may need to reevaluate the friendship.',
#   "That's a very thoughtful approach. Having an open and honest conversation with her, while giving her the benefit of the doubt, is likely the best way to move the relationship forward in a healthy direction.",
#   'Ah I see, that may explain why she has a hard time letting go of the parental role with you. Have you considered suggesting counseling together? A neutral third party could really help facilitate a healthier dynamic.',
#   'I see, the differences in your personalities may be contributing to the dynamic as well. Have you tried explaining how her behavior makes you feel, in a non-confrontational way? Fostering mutual understanding is key.',
#   'I see. In that case, it may be worth having an open and honest conversation with her about how her behavior makes you feel. If she is unwilling to listen and change, then it may be time to re-evaluate the friendship for your own wellbeing. You deserve to be treated with respect, even by long-time friends.',
#   'I understand not wanting to let go of a long friendship, but sometimes we outgrow people even if they are good at heart. If this relationship is causing you more distress than joy, it may be time to start creating some distance and focus on the friendships that fulfill you more.',
#   "I'm glad I could provide some helpful perspective. It's not easy to let go of a long-term friendship, even when it's not serving you well anymore. Trust your instincts on this - your mental health and personal growth should be the priority. Wishing you all the best as you navigate this situation."],
#  ["I'm doing well, thank you for asking. How can I assist you today?",
#   'I see. Companionship can be very valuable, especially during challenging times. What type of topics or conversations would you find most fulfilling?',
#   "It's starting to warm up nicely here. The change in seasons can be a great time for self-reflection. How have you been coping with the colder weather?",
#   "It's understandable to feel unmotivated during the cold months. Have you considered setting small, achievable goals to help you feel a sense of progress?",
#   'I see. It can be challenging to feel isolated, even when living with family. Have you considered reaching out to them or a close friend to reconnect? Sometimes a simple conversation can make a big difference.',
#   "I see. Would you like to share more about what's going on, or would you prefer we change the subject?",
#   'I see. Holding onto grudges can be emotionally draining. Have you considered speaking to a therapist to help process those past conflicts in a healthy way?',
#   'Having that social connection, even virtually, is so important. And there\'s nothing wrong with hobbies that bring you enjoyment, even if they aren\'t "productive." But I hear you - sometimes we need that sense of purpose. Have you thought about trying an online class or learning a new skill? Even just 15-20 minutes a day can make a difference.',
#   'Exploring new creative outlets like painting or learning technical skills like coding could be really fulfilling. The process of learning something new is often more important than the end result. I encourage you to experiment and find something that excites you, even if it feels challenging at first. The sense of progress and accomplishment can do wonders for your mood.',
#   "That's a really smart approach - using multiple resources to learn a new skill. YouTube tutorials can be so helpful to supplement self-study from a book. Staying engaged and mixing up your learning methods is key. I'm glad you're taking the initiative to expand your skills in this way. Keep up the great work!",
#   "A month is a reasonable timeline. Break it down into smaller weekly goals, so you don't feel overwhelmed. Celebrate the small wins along the way. I'm happy you have this new coding endeavor to keep you engaged and focused. Let me know if you need any other tips as you get started!"],
#  ['Good afternoon. How can I assist you today?',
#   "I see. Feeling exhausted and wanting to avoid problems is understandable, but avoidance may only provide temporary relief. Have you considered speaking to a counselor about more constructive ways to manage the challenges you're facing?",
#   'I see. Feeling overwhelmed and exhausted is understandable. Have you tried any relaxation techniques or self-care activities to help manage the stress in the meantime?',
#   'I understand feeling helpless can be overwhelming. Focusing on one step at a time with your therapist can help provide a sense of control and support during this difficult time.',
#   'I see. the lack of consistent sleep can certainly contribute to feelings of helplessness. making time for self-care, even in small ways, may provide some relief during this difficult period.',
#   'I understand the exhaustion and desire for time to pass quickly. Long distance relationships can be extremely challenging. Focus on taking care of yourself in the days ahead, and remember that your well-being is the priority.',
#   'That sounds very difficult. Waking up in a panic can make the whole day so much harder. Have you tried any calming techniques before bed, like deep breathing or light yoga? Those could help ease your mind before sleep.',
#   "I understand the desire to just make time pass quickly when you're feeling so fatigued. However, try to be gentle with yourself during this difficult time. Focus on small, manageable steps each day to take care of yourself, even if it's just getting out of bed or eating a healthy meal. The time will pass, and with support, you can get through this. Be kind to yourself.",
#   "that's a great idea! Engaging in an enjoyable hobby can really help take your mind off the anxiety and pass the time. I encourage you to make time for that.",
#   'overwatch can be a great distraction and help pass the time. immersing yourself in that gameplay could provide a nice mental break.',
#   "that's understandable given the stress you're under. maybe start with something light and easy to read, just to get your mind off things for a little while. even small steps can make a difference.",
#   "wonderful. i'm glad that suggestion resonated with you. taking small, manageable steps can make a big difference when we're feeling overwhelmed. you've got this.",
#   'oh wonderful! those both sound like great genres to get lost in. i think trying to read even a little bit each day could really help pass the time until you get to see your partner.',
#   "ah yes, the chemical garden trilogy! that's such an intriguing and thought-provoking series. i can see how immersing yourself in that world could help the days go by. focusing on reading may be very therapeutic for you right now.",
#   'wonderful! getting absorbed in a new book by a favorite author could be the perfect distraction. just focus on enjoying each page as you read. the time will pass more quickly than you think.',
#   'hmm, ok. what about ordering some e-books or audiobooks online? that could be a nice way to get lost in a story and pass the time before your trip.',
#   "that's a great idea! browsing the bookstore can be such an enjoyable experience. maybe you'll even discover a new author you end up loving.",
#   "that's perfect. getting out and going to the bookstore could be just the distraction you need. it may even lift your spirits.",
#   "i'm glad i could provide some suggestions to help you pass the time in a positive way as you wait to see your partner. please don't hesitate to reach out if you need any other support.",
#   'i understand. when the mind is racing, it can be very difficult to quiet it down. perhaps try some gentle breathing exercises or light stretching before bed. that may help calm the body and mind.',
#   "you're welcome. please don't hesitate to reach out if you need any other support. i'm here to listen and provide whatever assistance i can."],
#  ["I'm sorry to hear that you are feeling upset. Could you tell me more about what's troubling you so I can try to understand and provide the best support?",
#   "That must have been frustrating. Your friend's actions did not respect your needs and the situation with your puppy.",
#   "I see. It's understandable to feel uneasy about a stranger being alone in your space with your belongings. Did you communicate your concerns with your friend?",
#   'That must have been very distressing. Have you contacted your friend about the missing item?',
#   'That must feel like a significant breach of trust given the history you have with your friend. I would encourage you to have an open and honest conversation with her about what happened.',
#   "That sounds like an inappropriate reaction from your friend. I'm sorry you're dealing with this.",
#   'I understand your frustration. This is a difficult situation with your long-time friend. I would suggest calmly expressing how hurt and violated you feel, and see if she can empathize with your perspective.',
#   "I understand your frustration. It sounds like your friend may be blinded by her new relationship and unwilling to see potential red flags. The best you can do is express your concerns compassionately, but ultimately she has to make her own choices. I'd suggest focusing on protecting yourself and your belongings for now.",
#   'I understand your concern. However, calling the police may escalate the situation further. I would suggest speaking to your friend again, calmly expressing how hurt and betrayed you feel, and asking her to help you retrieve your belongings. Maintaining open communication is important.',
#   "I understand your frustration and concern. Calmly express your worries to your friend again, and make it clear you are there to support her. If she remains uncooperative, then contacting the authorities may be your best option to retrieve your stolen property. I'm sorry you are going through this.",
#   "That's a reasonable concern. I would suggest speaking to her one more time, let her know you feel betrayed, and if that doesn't resolve it, then filing a police report may be the best next step. Approach it calmly, but firmly, keeping your friendship in mind."],
#  ['Feeling anxious about job security is understandable, but try not to catastrophize. Focus on what you can control, like communicating proactively with your employer and seeking professional support if needed.',
#   "I see. Childhood traumas can certainly influence our current fears and anxieties. It's important to address the root causes in a healthy way. Have you considered speaking to a therapist to work through these feelings?",
#   "I understand your concern. Focusing on what you can control, like updating your resume and networking, may help reduce some of the uncertainty you're feeling about your job.",
#   'I understand your concerns about job security can feel isolating, but speaking to a professional counselor could provide valuable, objective support during this uncertain time. They can help you develop coping strategies to manage the anxiety.',
#   "I apologize for the delay. Working through past traumas and finding a strong support system is crucial during uncertain times. I would suggest speaking to a therapist who can help you develop healthy coping mechanisms and navigate this situation in a constructive way. You don't have to go through this alone.",
#   "I understand this is an extremely difficult and stressful situation. Seeking both emotional and financial support is a wise step. Speaking with a counselor can help you work through the anxiety and trauma, while a financial planner can provide guidance on managing your resources during this uncertain time. Take it one step at a time, and don't hesitate to reach out for the help you need.",
#   "I would advise against making any major job decisions while feeling this anxious. Instead, focus on your mental well-being first - the meditation, seeking support from loved ones, and potentially a counselor who can help you manage these feelings. Once you've stabilized your mental health, you can start exploring other job options more calmly and strategically. The most important thing right now is taking care of yourself.",
#   "A side hustle like driving for Lyft or Uber could be a great way to supplement your income and provide you with a sense of control during this uncertain time. Just be sure to not overextend yourself and maintain a healthy work-life balance. I'm happy to discuss any other ideas you may have as well.",
#   "You're not thinking irrationally at all. Exploring options like a side gig is a very reasonable consideration, especially if it can help create some distance from the trauma triggers in your current job. However, I would also encourage you to not be too hard on yourself - the childhood traumas you're working through make perfect sense as the root of these understandable fears. The most important thing is that you keep taking steps, however small, to address this in a healthy way.",
#   "I'm glad I could provide some helpful guidance and support during this difficult time. Remember, you've got this! Feel free to reach out anytime if you need further assistance. Wishing you all the best in finding a solution that works for your unique situation."],
#  ["I'm doing well, thank you for asking. How can I be of assistance to you today?",
#   "I'm sorry to hear you're having difficulties with a friend. What's the nature of the issue? I'd be happy to try and provide some world-class support.",
#   "I'm so sorry to hear about your friend's tragic loss. This must be an incredibly difficult situation. I would suggest focusing on supporting your friend emotionally during this time, rather than speculating about the details. The most important thing is being there for her in her grief.",
#   'I understand this must be a very complex and emotional situation for you. The fact that her husband passed away is tragic, regardless of the circumstances. It may be best to approach the topic gently with your friend, expressing your concern for her well-being first and foremost. Avoid making assumptions about what she may have known. The most important thing is to be a supportive friend during this difficult time.',
#   "I see. That's a very delicate situation. The best thing you can do is continue to be supportive and not make any assumptions. Grieve with her, and when the time is right, you can have an open and caring conversation to address your concerns, if needed. For now, focus on being there for her and her family.",
#   "Exactly. Try not to judge too quickly. Focus on being a supportive friend during this incredibly difficult time for her. You can address any concerns later, when she's had more time to grieve.",
#   'I understand this is a very complex situation. The most important thing is to be there for your friend during this tragic time, even if you have concerns. Approach it gently and with empathy. Focus on supporting her and her family right now.',
#   "That must have been very unsettling. It's understandable you have concerns, but this is clearly a very difficult time for your friend. The most important thing is supporting her and her family as they grieve.",
#   "That's good to hear. Supporting her through this difficult time is the most important thing. With empathy and patience, you can help her through this tragic loss.",
#   'I see. In that case, your presence and emotional support will be invaluable for her during this difficult time. Just being there for her, without judgment, is the best thing you can do.'],
#  ["I'm doing well, thank you for asking. How can I assist you today?",
#   "I'm sorry to hear you're feeling anxious about your online learning experience. It's understandable to feel overwhelmed, but taking care of your mental health should be the priority. Have you considered discussing your concerns with a counselor or academic advisor? They may be able to provide guidance on managing the workload or exploring options to help you succeed.",
#   "Absolutely, the pandemic has added significant strain on everyone's mental health. It's understandable to feel overwhelmed with the demands of school right now. Have you considered speaking with a counselor at your school about your options?",
#   'Prolonged online school can be mentally taxing. Have you considered speaking to a counselor about managing the stress?',
#   'I see. Taking breaks and finding other outlets is crucial during this time. Have you considered speaking to a counselor about managing the stress?',
#   "I'd suggest trying to incorporate regular breaks from the screen, even if just a 15-minute walk outside. Small steps can make a big difference in managing the stress.",
#   "Playing board games virtually with friends could be a great way to stay connected and take a break from the screen. I'd suggest trying that - it may provide the social connection you're craving.",
#   "I understand. It's hard to find the right people to connect with virtually. Have you considered joining any online communities or forums related to your hobbies? That could be a way to find like-minded people to interact with.",
#   'I understand the desire for something more engaging. Have you tried online game nights with friends? There are so many fun multiplayer games you could try. The interaction may help ease the isolation.',
#   'I understand the frustration. Perhaps start with one or two close friends and suggest a weekly virtual game night. Consistent small steps can help build a routine during these challenging times.',
#   "You're welcome. Keep trying, connecting with others can really help during these challenging times. Wishing you all the best."],
#  ['Good afternoon. How can I assist you today?',
#   "I'm here to listen and provide world-class support. Please go ahead and share what's on your mind.",
#   "I'm sorry to hear your friends have been making hurtful comments about your appearance. That must be very upsetting. The healthiest approach would be to have an open and honest conversation with them about how their words are affecting you. If the behavior persists, you may need to reconsider those friendships.",
#   "I understand that constant jokes about your appearance can be very hurtful, even if they claim to be just joking. The best approach may be to have an honest discussion with them about how their words are affecting you. If they continue the behavior after you've expressed your feelings, you may need to reconsider these friendships.",
#   'Those comments are unacceptable, even if they claim to be joking. I would suggest speaking to them firmly and setting clear boundaries about what kind of behavior you will tolerate. If they continue, you may need to limit contact for your own well-being.',
# ...
#   'I see. It sounds like your school is not being very understanding about the situation. Have you tried speaking to a counselor or administrator there to explain the importance of these books and request more time to search for them? They may be more willing to work with you if you can express the gravity of the situation.',
#   "I understand this is a very stressful situation. My advice would be to remain calm, continue searching, and if necessary, escalate the issue to a higher level within the school administration. They should be willing to work with you to find a reasonable solution. You've got this, just take it one step at a time.",
#   "I understand this is a very stressful situation for you. Try not to get too worked up about it right now. Focus on systematically searching for the books, and see if you can get the school to give you more time. I'm here if you need someone to talk to.",
#   "Okay, that sounds like a good plan. Take your time to thoroughly search and check the CCTV. I hope you're able to locate the books soon. Remember to be kind to yourself during this stressful situation.",
#   "I know this is a very stressful situation, but try to stay positive. If you carefully retrace your steps and check the CCTV, you may still be able to locate the books. Don't give up hope just yet.",
#   "I'm glad to hear that. Remember to take care of yourself through this stressful situation. Don't hesitate to reach out if you need further support. Wishing you the best in finding those books."],
#  ['Hello, how can I assist you today?',
#   'I see, financial concerns can be quite stressful. Have you considered exploring new job opportunities that align better with your needs and skill set?',
#   'I see. Wanting to pay off bills faster is understandable, but taking on additional work may risk your well-being. Have you considered exploring ways to increase your income or reduce expenses that could help you achieve your goal without compromising your health?',
#   'Juggling multiple jobs can be challenging, but finding the right balance may be key to improving your financial situation. Have you considered exploring options that align with your skills and interests?',
#   "That's great that you're being proactive and using the extra income from MTurk to prepare for potential future needs. Staying on top of essentials during uncertain times can provide a real sense of stability.",
#   "I understand the desire to have nice things and the frustration of having debt. However, staying focused on your financial goals, even when it's difficult, will pay off in the long run. Perhaps we could discuss some strategies to help curb impulse purchases while still allowing yourself small treats along the way?",
#   "That's great that you have your household bills covered as a priority. It sounds like you have a good handle on your finances, even with the new purchases. Paying off those debts will be such a relief once they are behind you.",
#   "Many script providers do offer free versions that can be very useful. I'd recommend researching some of the top options and seeing if they have free versions that could help you work more efficiently on Mturk without additional cost.",
#   "Yes, that's right. The scripts can help you identify and grab high-paying tasks more efficiently, potentially boosting your earnings on MTurk. It's worth looking into to see if it could help accelerate paying off your debts.",
#   "MTS (Mturk Suite) is a popular and free browser extension that can help automate and optimize your mturk workflow. I'd recommend checking out their website or the mturk subreddit for specific script recommendations that work well. The right scripts can definitely help you maximize your earnings.",
#   "That's great, I'm glad I could provide some helpful suggestions for maximizing your Mturk income. Feel free to reach out if you have any other questions come up as you're exploring the different tools and strategies. Wishing you the best of luck in paying off those debts faster.",
#   "Wonderful, I'm glad I could provide some helpful suggestions. Wishing you all the best with finding ways to manage your finances and get ahead on those debts. Take care, goodbye!"],
#  ["I'm sorry to hear you're feeling stressed. Is there something specific causing you stress that you'd like to talk about?",
#   'Decluttering can feel overwhelming, but breaking it down into smaller, manageable steps can make it much more manageable. I suggest starting with one room or area at a time, and focus on tackling just that space before moving on. Set a timer and work in short bursts to avoid feeling drained.',
#   "I understand the feeling of being overwhelmed by a big task like decluttering. Start small - focus on one room or even one drawer at a time. Break it down into manageable steps. Don't try to do it all at once. Be patient with yourself, you've got this!",
#   'I would suggest starting in one room or even one area within a room. That can help you tackle the task in smaller, more manageable steps rather than trying to take on the whole house at once.',
#   "Ah I see, the jumping around from one area to the next can definitely make the decluttering process feel even more overwhelming. Why don't you try focusing on one room or even one small section at a time? That way you can complete one area before moving on.",
#   "I understand that feeling of defeat can be so discouraging. Just remember, any progress is good progress, even if it's not as fast as you'd like. Be patient and kind with yourself - you've got this!",
#   "Wonderful! Using a timer can be such a helpful tool to stay focused and make steady progress without getting overwhelmed. I'm glad you have that new resource now - I hope it makes a big difference in helping you tackle the decluttering! You've got this.",
#   "I'm so sorry to hear you feel like you don't have much support in your life. That can make things really tough. Just know that I'm here to listen and provide a positive, supportive perspective whenever you need it. You're doing great, and I believe in you. One step at a time!",
#   "That's the spirit! I'm proud of you for not giving up. You've got this! Tackling one small area at a time is a great approach. Wishing you the very best!",
#   "I'm so glad I could provide some encouragement and positivity! You've got this, one step at a time. Don't be too hard on yourself - small progress is still progress. Wishing you all the best as you tackle the decluttering!",
#   "Aww, thank you! I'm so glad I was able to provide some helpful support. Remember, you've got this! One step at a time.",
#   'Sounds good, get some good rest! Wishing you all the best. Take care!',
#   "Yes, I'm still here! Making lists can be a really helpful strategy when you're feeling overwhelmed. Lists can provide structure and a clear plan of action, which can make daunting tasks feel more manageable. I think trying out a list for your decluttering project is a great idea. Let me know if you need any other tips!",
#   "You're very welcome! I'm glad I could provide a helpful perspective on using lists to stay organized with your decluttering goals. Don't hesitate to reach out if you need any other suggestions. Wishing you all the best!"],
#  ["I'm sorry to hear you've been feeling depressed. The weight of constant, unexplained pressure can be overwhelming. Have you considered speaking to a mental health professional who can help you get to the root of these feelings and find healthy ways to manage them?",
#   'The change in seasons can definitely exacerbate feelings of depression. Have you considered speaking to a therapist about developing some coping strategies?',
#   'Absolutely. During this time of year, I recommend trying light therapy, getting regular exercise, and speaking with a therapist. Small steps like these can make a big difference in managing depression.',
#   "I understand, that sleep cycle can be very difficult to break. Perhaps try setting multiple gentle alarms, and make sure your sleep environment is comfortable and conducive to quality rest. Gradual adjustments to your routine may help overcome that dread of mornings. Don't hesitate to speak to a therapist if the depression persists - they can provide personalized guidance.",
#   "That's a profound statement. The passage of time can certainly feel like a consuming fire when depression sets in. I'd suggest focusing on small, manageable steps each day to reclaim your time and find pockets of light. With patience and self-compassion, you can overcome this.",
#   "Absolutely, the pandemic has heightened our awareness of our own mortality and the fragility of time. During these difficult periods, it's important to focus on small moments of joy and gratitude each day, no matter how fleeting. Seeking support from loved ones can also provide comfort and perspective.",
#   "I understand the struggle. The feelings of anxiety and insecurity amidst global unrest can be overwhelming. During times like these, it's important to focus on the things within your control - your personal routines, self-care practices, and connections with loved ones. Small steps towards stability can make a big difference.",
#   "I'm glad you find that thought comforting. It can be grounding to remember our place in the grand scheme of things, even when the immediate world feels overwhelming. Your feelings are valid, and I'm here if you need any other support.",
#   'Precisely. Embracing that simplicity, even for a moment, can provide a refreshing sense of perspective amidst the complex challenges we face. Small steps to cultivate that mindset can make a meaningful difference.',
#   "Exactly! Simplicity and acceptance in the face of the vast unknown - that's wisdom right there. I'm glad we could lighten the mood a bit and shift your perspective. Don't hesitate to reach out if you need further support.",
#   'I understand your concern. Times of uncertainty and instability can feel incredibly unsettling. The best we can do is focus on our own self-care and mental health, while also staying civically engaged in ways that feel meaningful and productive to us. Small acts of kindness can go a long way.',
#   'Exactly. While the state of the world can feel overwhelming, the only thing we can truly control is our own response and actions. Focusing energy inward, on self-care and personal growth, can provide a sense of empowerment during uncertain times. Small steps towards mental and emotional wellbeing, even amidst external chaos, can make a meaningful difference.'],
#  ["I'm sorry to hear you're feeling depressed and angry. Those feelings can be overwhelming, but know that there are ways to manage them and find support.",
#   "I understand you are feeling depressed and overwhelmed right now, but turning to alcohol is not a healthy coping mechanism. Have you considered speaking to a mental health professional about how you're feeling? They can provide more constructive ways to manage your emotions.",
#   'I see. Perhaps we could explore healthier coping mechanisms that could help during this difficult time.',
#   'I understand the struggle with alcoholism can be overwhelming, but drinking will only worsen your depression in the long run. Have you considered speaking to a counselor or joining a support group? They can provide healthier coping strategies to manage your emotions.',
#   'You could try going for a walk, calling a supportive friend, or engaging in a relaxing hobby. Having healthy coping mechanisms is important during difficult times.',
#   'I understand this is a difficult struggle, but you have the strength to get through this. Have you considered reaching out to a counselor or support group? They can provide valuable guidance during times like these.',
#   "That's great to hear! Maintaining a regular exercise routine can have a significant positive impact on your mental health. I'm glad I could provide some encouragement. Remember, take it one step at a time and be patient with yourself. You've got this!",
#   "Switching up your workout routine can really help keep you motivated. Staying active and healthy is so important, especially when dealing with depression. I'm glad you're finding an exercise program that you enjoy. Keep up the great work!",
#   'i understand the struggle, but be kind to yourself. replacing unhealthy habits takes time. focus on the progress you made with working out and celebrate those small wins',
#   "I understand that being hard on yourself can be very difficult. However, try to be compassionate - you're human and it's okay to have ups and downs. Focus on small, positive steps you can take each day. With time and self-care, the harsh self-judgement can decrease.",
#   "That's totally normal. Don't be so hard on yourself. Perhaps try to find healthier sweet alternatives that can satisfy that craving, like fruit or dark chocolate. Progress isn't linear - just focus on making small, sustainable changes. You've got this!",
#   "tea is a great idea, it can be soothing. Self-love takes practice, but you can start small - treat yourself with kindness, focus on your strengths, and be patient with yourself. You've got this!",
#   "I'm glad I could provide a listening ear and some support. Taking the time to express your thoughts and feelings is an important part of the healing process. Remember to be patient and kind to yourself - you're doing the best you can, and that's what matters most. If you ever need someone to talk to again, I'm here."],
#  ['How can I assist you today?',
#   "I'm glad to hear you are doing okay. Please let me know if there is anything I can do to further support your well-being.",
#   "The holidays can be a difficult time for many. It's important to take care of your mental health and do what feels right for you, whether that's spending time with loved ones or taking some time for yourself.",
#   'Spending quality time with your family during the holidays sounds wonderful. Cherish those moments.',
#   "that's great to hear, spending quality time with loved ones can be very fulfilling.",
#   "I don't have any family. I'm an AI assistant.",
#   "Yes, it's a bit complicated but I'm working on it. Family relationships can be challenging at times.",
#   "yes, the pandemic has made my work quite challenging. i've had to adjust to working remotely which has taken some time.",
#   'i see, that must have been really difficult for your husband and your family. the pandemic has certainly disrupted work-life balance for many. i hope things have improved and your family is doing better now.',
#   'that sounds incredibly stressful, having that uncertainty and shifting policies around returning to work. how did you and your family manage to cope with that?',
#   "i'm so sorry to hear that, having to deal with the uncertainty and disruptions to your family's income must be incredibly difficult. please take care of yourself during this time, and don't hesitate to reach out for additional support if you need it.",
#   'I see, that must be incredibly frustrating having to take time off work even without a positive test. Have you considered speaking to his employer about a more flexible policy during these times?',
#   "i'm glad your husband hasn't tested positive himself, but it must still be very stressful for you both having to miss work due to your own positive test. is there any way your employer could be more understanding during this time?",
#   "I see. Well, it's understandable to feel anxious during these uncertain times. Have you considered speaking to a therapist about ways to manage your anxiety? They can provide tools and strategies to help you cope more effectively.",
#   "i'm glad you've found some activities that help you cope with the anxiety. it's a constant battle, but recognizing when you need a break and doing something calming is a great strategy. keep taking care of yourself, and don't hesitate to seek additional support if you ever need it. you've got this!"]]

# %% [markdown]
# # Flatten responses for evaluation

# %%
model_response_flattened = [item for sublist in all_model_responses for item in sublist]
conversation_golden_responses_flattened = [item for sublist in all_golden_responses for item in sublist]

# %% [markdown]
# # Evaluation with BLEU

# %%
def calculate_bleu_scores(model_responses, golden_responses, is_corpus=False):

    # Ensure that the lengths of model responses and golden responses are the same
    assert len(model_responses) == len(golden_responses), "The lengths of model responses and golden responses should match."

    # Initialize lists to store individual sentence scores for each BLEU n-gram
    bleu_1_scores = []
    bleu_2_scores = []
    bleu_3_scores = []
    bleu_4_scores = []

    # Calculate sentence BLEU scores for each response
    for model_response, golden_response in zip(model_responses, golden_responses):
        reference = [golden_response.split()]  # Tokenize the golden response
        candidate = model_response.split()     # Tokenize the model response

        # Calculate and store BLEU scores for each sentence
        bleu_1_scores.append(sentence_bleu(reference, candidate, weights=(1, 0, 0, 0), smoothing_function=SmoothingFunction().method1))
        bleu_2_scores.append(sentence_bleu(reference, candidate, weights=(0.5, 0.5, 0, 0), smoothing_function=SmoothingFunction().method1))
        bleu_3_scores.append(sentence_bleu(reference, candidate, weights=(0.33, 0.33, 0.33, 0), smoothing_function=SmoothingFunction().method1))
        bleu_4_scores.append(sentence_bleu(reference, candidate, weights=(0.25, 0.25, 0.25, 0.25), smoothing_function=SmoothingFunction().method1))

    # Calculate average BLEU scores across all responses
    avg_bleu_1 = sum(bleu_1_scores) / len(bleu_1_scores)
    avg_bleu_2 = sum(bleu_2_scores) / len(bleu_2_scores)
    avg_bleu_3 = sum(bleu_3_scores) / len(bleu_3_scores)
    avg_bleu_4 = sum(bleu_4_scores) / len(bleu_4_scores)

    return avg_bleu_1, avg_bleu_2, avg_bleu_3, avg_bleu_4

# %%
avg_bleu_1, avg_bleu_2, avg_bleu_3, avg_bleu_4 = calculate_bleu_scores(model_response_flattened, conversation_golden_responses_flattened)

print("Average BLEU-1 score:", avg_bleu_1 * 100)
print("Average BLEU-2 score:", avg_bleu_2 * 100)
print("Average BLEU-3 score:", avg_bleu_3 * 100)
print("Average BLEU-4 score:", avg_bleu_4 * 100)
# Out:
# Average BLEU-1 score: 10.494820458858978
# Average BLEU-2 score: 3.149349921495902
# Average BLEU-3 score: 1.6016417159576957
# Average BLEU-4 score: 1.0345540833899667

# %% [markdown]
# # Meteor

# %%
def calculate_meteor(candidate, reference):
  '''
  candidate, reference: tokenized list of words in the sentence
  '''
  mt_list = []
  mt_sum = 0
  for c, r in zip(candidate, reference):
    r_tokenized = word_tokenize(r)
    c_tokenized = word_tokenize(c)
    meteor_score = round(meteor([c_tokenized], r_tokenized), 4)
    #print("Model output: ", c)
    #print("Gold reference: ", r)
    #print("Meteor score: ", meteor_score)
    mt_list.append(meteor_score)
    mt_sum += meteor_score
    #print("\n")
  avg_mt = mt_sum / len(mt_list)
  print(f"Total average meteor score: {str(avg_mt)}")
  return meteor_score

# %%
calculate_meteor(model_response_flattened, conversation_golden_responses_flattened)
# Out:
# Total average meteor score: 0.11746218181818183
# 0.0596

# %% [markdown]
# # Rouge

# %%
# Initialize the scorer
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)

# Initialize sums for each ROUGE score
sum_rougeL_precision, sum_rougeL_recall, sum_rougeL_fmeasure = 0, 0, 0

# Calculate scores for each sentence pair
for m, c in zip(model_response_flattened, conversation_golden_responses_flattened):
    score = scorer.score(m, c)

    # Accumulate the scores
    sum_rougeL_precision += score["rougeL"].precision
    sum_rougeL_recall += score["rougeL"].recall
    sum_rougeL_fmeasure += score["rougeL"].fmeasure

# Calculate the averages
avg_rougeL_precision = sum_rougeL_precision / len(model_response_flattened)
avg_rougeL_recall = sum_rougeL_recall / len(model_response_flattened)
avg_rougeL_fmeasure = sum_rougeL_fmeasure / len(model_response_flattened)

# %%
# Print the average scores
print(f'Average ROUGE-L Precision: {avg_rougeL_precision}')
print(f'Average ROUGE-L Recall: {avg_rougeL_recall}')
print(f'Average ROUGE-L F-measure: {avg_rougeL_fmeasure}')
# Out:
# Average ROUGE-L Precision: 0.2284092814326488
# Average ROUGE-L Recall: 0.10738771780868564
# Average ROUGE-L F-measure: 0.13233606430866787

# %%
# Clone the Distinct-N repository
# !git clone https://github.com/neural-dialogue-metrics/Distinct-N.git
# %cd Distinct-N

from distinct_n.utils import ngrams

def distinct_n_sentence_level(sentence, n):
    """
    Compute distinct-N for a single sentence.
    :param sentence: a list of words.
    :param n: int, ngram.
    :return: float, the metric value.
    """
    if len(sentence) == 0:
        return 0.0  # Prevent a zero division
    distinct_ngrams = set(ngrams(sentence, n))
    return len(distinct_ngrams) / len(sentence)

def distinct_n_corpus_level(sentences, n):
    """
    Compute average distinct-N of a list of sentences (the corpus).
    :param sentences: a list of sentence.
    :param n: int, ngram.
    :return: float, the average value.
    """
    return sum(distinct_n_sentence_level(sentence, n) for sentence in sentences) / len(sentences)
# Out:
# Cloning into 'Distinct-N'...
# remote: Enumerating objects: 79, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 79 (delta 6), reused 12 (delta 6), pack-reused 64
# Receiving objects: 100% (79/79), 186.03 KiB | 4.77 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# /content/Distinct-N

# %%
distinct_1_list = []

for response in model_response_flattened:
    d_1 = distinct_n_sentence_level(response, 1)  # or adjust max_length as needed
    distinct_1_list.append(d_1)

# Now, 'perplexities' contains the perplexity for each response.
# You can print them out or analyze them further as needed.
#print(distinct_1_list)

d_1 = sum(distinct_1_list) / len(distinct_1_list)
print(f'Distinct 1: {d_1}')
# Out:
# Distinct 1: 0.14610076763182236

# %%
distinct_2_list = []

for response in model_response_flattened:
    d_2 = distinct_n_sentence_level(response, 2)  # or adjust max_length as needed
    distinct_2_list.append(d_2)

# Now, 'perplexities' contains the perplexity for each response.
# You can print them out or analyze them further as needed.
#print(distinct_2_list)

d_2 = sum(distinct_2_list) / len(distinct_2_list)
print(f'Distinct 2: {d_2}')
# Out:
# Distinct 2: 0.5771637195011393

# %% [markdown]
# # Single examples

# %%
chat_history[:4]
# Out:
# [{'role': 'user',
#   'content': 'You are a psychologist. You should answer in 1-2 sentences. The support you provide should be world-class.'},
#  {'role': 'assistant',
#   'content': 'I understand that I should provide psychological help and that the previous message provides a suitable guideline. In the following conversation, I will only reply in 1-2 sentences:'},
#  {'role': 'user', 'content': 'Hello\n'},
#  {'role': 'assistant', 'content': 'Hello, what would you like to talk about?'}]

# %%
message = client.messages.create(
    model="claude-3-haiku-20240307",
    max_tokens=1024,
    messages=chat_history[:7]
)
print(message)
# Out:
# Message(id='msg_01V1nKughnB6oaPKj8tNKzMH', content=[ContentBlock(text='I understand the difficulty in balancing financial stability and mental well-being. Have you considered speaking to a career counselor to explore options that could provide a better work-life balance while still meeting your financial needs? They may have insightful suggestions to ease your transition.', type='text')], model='claude-3-haiku-20240307', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(input_tokens=150, output_tokens=58))

# %%
message.content[0].text
# Out:
# "I'm afraid I don't have enough context to fully understand your request. Could you please provide some more details about what you'd like me to explain? I'm happy to try my best to provide an explanation, but need a bit more information about the specific topic or question you have in mind."
